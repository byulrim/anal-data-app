# %%
from urllib import request

url = "https://raw.githubusercontent.com/rickiepark/llm-from-scratch/main/ch02/01_main-chapter-code/the-verdict.txt"
file_path = "the-verdict.txt"

request.urlretrieve(url, file_path)
# Out:
# ('the-verdict.txt', <http.client.HTTPMessage at 0x1da7729c5c0>)

# %%
raw_text = ""

with open("the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

print("총 문자 개수:", len(raw_text))
print(raw_text[:99])
# Out:
# 총 문자 개수: 20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %%
import re

text = "Hello, world. Is this-- as test?"
result = re.split(r"([,.:;?_!\"()']|--|\s)", text) # Capture Group
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['Hello', ',', 'world', '.', 'Is', 'this', '--', 'as', 'test', '?']

# %%
preprocessed = re.split(r"([,.:;?_!\"()']|--|\s)", raw_text)
preprocessed = [item.strip() for item in preprocessed if item.strip()]

print(len(preprocessed))
print(preprocessed[:30])
# Out:
# 4690
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in']
