# %%
# stack
lst = [1, 2, 3, 4, 5]
print(lst)
lst.append(10) # push
print(lst)
lst.append(20)
print(lst)
a = lst.pop() # pop
print(lst)
print(a)
b = lst.pop()
print(lst)
print(b)

# %%
word = input("Input a word: ")
word_lst = list(word)
print(word_lst)

for _ in range(len(word_lst)):
    print(word_lst.pop())
    print(word_lst)

# %%
word = "hello, world"
print("".join(reversed(word)))

# %%
print(word[-1::-1])

# %%
#queue
lst = [1, 2, 3, 4, 5]
print(lst)
lst.append(10) # put
print(lst)
lst.append(20)
print(lst)
a = lst.pop(0) # get
print(lst)
print(a)
b = lst.pop(0)
print(lst)
print(b)

# %%
tup = (1, 2, 3)
print(type(tup), tup)

# %%
print(tup + tup, tup * 2)
print(len(tup))

# %%
lst = list(tup)
lst.append(4)
lst.append(5)
lst.insert(0, 6)
tup = tuple(lst)
print(tup)

# %%
s = set([1, 2, 3, 1, 2, 3])
print(s)
s.add(1) # 단일값 추가
print(s)
s.remove(1) # 요소가 없는 경우, KeyError 발생
print(s)
s.update([1, 4, 5, 6, 7]) # 여러값(iterator) 추가
print(s)
s.discard(8) # 요소가 없는 경우, Error 발생 X
print(s)
s.clear() # 전체 요소 삭제
print(s)

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {3, 4, 5, 6, 7}

print(s1.union(s2)) # 합집합
print(s1 | s2)

print(s1.intersection(s2)) # 교집합
print(s1 & s2)

print(s1.difference(s2)) # 차집합
print(s1 - s2)

print(s1.symmetric_difference(s2)) # 대칭 차집합
print(s1 ^ s2)

# %%
country_code = {"America": 1, "Korea": 82, "China": 86, "Japan": 81}

print(country_code, type(country_code))

# %%
for item in country_code.items():
    print(item)

# %%
country_code["German"] = 49
print(country_code)
country_code["German"] = 55
print(country_code)

# %%
for k, v in country_code.items():
    print(f"Key: {k: <7}, Value: {v:2d}")

# %%
"Korea" in country_code.keys()

# %%
82 in country_code.values()
