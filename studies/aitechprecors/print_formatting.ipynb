# %%
print("I eat %d apple." % 3)
print("I eat %s apple." % "five")
number = 3; day = "three"
print("I ate %d apples. I was sick for %s days." % (number, day))
print("Product: %s, Price per unit: %f." % ("Apple", 5.243))
# Out:
# I eat 3 apple.
# I eat five apple.
# I ate 3 apples. I was sick for three days.
# Product: Apple, Price per unit: 5.243000.

# %%
print("Art: %5d, Price per Unit: %8.2f" % (453, 59.058))

temp_a = 453; temp_b = 59.058
print(f"Art: {temp_a: >5}, Price per Unit: {temp_b: >8,.2f}")
# Out:
# Art:   453, Price per Unit:    59.06
# Art:   453, Price per Unit:    59.06

# %%
age = 10
name = "unknown"

print("I'm {} years old.".format(age))
print("My name is {} and {} years old.".format(name, age))
# Out:
# I'm 10 years old.
# My name is unknown and 10 years old.
# Product: Apple, Price per unit: 5.24.

# %%
print("Product: {}, Price per unit: {:.2f}.".format("Apple", 5.243))
# Out:
# Product: Apple, Price per unit: 5.24.

# %%
def convert_c_to_f(celsius: float) -> float:
    return (((9 / 5) * celsius) + 32)

print("본 프로그램은 섭씨를 화씨로 변환해주는 프로그램입니다.")
print("변환하고 싶은 섭씨 온도를 입력해 주세요:")
celsius = float(input())
fahrenheit = convert_c_to_f(celsius)

print(f"섭씨온도 : {celsius:.2f}")
print(f"화씨온도 : {fahrenheit:.2f}")
# Out:
# 본 프로그램은 섭씨를 화씨로 변환해주는 프로그램입니다.
# 변환하고 싶은 섭씨 온도를 입력해 주세요:
# 섭씨온도 : -100.00
# 화씨온도 : -148.00
